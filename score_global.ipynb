# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %% [markdown]
# # Diseño del Score Global de riesgo VereData V1.0
#
# En este notebook se encuentra el procedimiento para el diseño de la primera versión del score global de riesgo de VereData. Este indicador esta compuesto por 40 variles dividida en cinco compoentes: contexto socioeconómico, infraestructura, criminalidad, conflcito armado y ambiental. (Ver ilustración 1)
#
# Las variables tienen periodicidad anual, y se usa su último año disponible (En algunos casos es necesario actualizarlas).
#
# Nota: al importar la base se elimina la primera columna que no tiene información, y los ROS de Bancolombia, porque es información confidencial.

# %%
df = pd.read_csv("variables.csv", converters={'coddane':str})

# %%
df = df.drop(['Unnamed: 0', 'num_ros_perc'], axis=1)

# %% [markdown]
# ## Transformación de variables:
#
# Las variables pasan por un proceso de transformación para reducir el efecto de factores externos sobre ellas que pueden dificultar el análisis del indicador.
#
# Por ejemplo, algunos municipios tienen una población muy grande en comparación a los demás, por lo que es normal que sucedan una mayor cantidad de delitos, por lo tanto, es necesario transformarlos a tasas por cierta cantidad de habitantes, para poder compararlo con los demás municipios.
#
# Más adelante se pondrá una tabla señalando que transformaciones se hicieron a qué variables.

# %% [markdown]
#  - Transformación a tasas: algunas variables relacionadas con la población se transformaron a tasas para mejorar la capacidad de análisis del score y comparación entre los municipios, las de delitos y otras variables relacionadas con la población se tranformaron en tasas de cada 100.000 habitantes, mientras las que se relacionaban mejor con la extensión geográfica se tranformo en tasas por hectareas.
#
#  - Transformación de dummies a continuas: cuandos se normaliza una variable dummy no cambia su valor, dandole la calificación máxima a los municipios que tienen 1, y la mínima a los que tienen 0. Estas    calificaciones tienen mucho peso sobre el indicador hasta el punto de sesgar sus resultados.
#
#  - Transformación de dummies: las variables dummies tienen valores fijos de 1 y 0 que al normalizar la seríe le da la máxima puntuación a los municipios con valores 1 y la mínima a los de 0. Esto causaba que estas variables tuvieron un peso mayor en el score, comparación con las variables continuas, por tal motivo, se hicieron aproximaciones con valor agregado.

# %%
#transformación de dummies y discretas
df['fronterizo_x_va'] = df['mpio_fronterizo']*df['va_ppa_2019']
df['pasofr_x_va'] =  df['paso_fr']*df['va_ppa_2019']
df['puertos_x_va'] =  df['puerto_libre']*df['va_ppa_2019']
df['zf_x_va'] = df['suma_zf']*df['va_ppa_2019']
df['rios_x_ha'] = df['presencia_rios']/df['ha_municipal']

# %%
#creación de proxys
df['desigualdad'] = df['ipm_2018']*df['va_ppa_2019']

# %%
df.columns
# Out:
# Index(['coddane', 'MPIO_y', 'DPNOM_x', 'gobierno_abierto_2016',
#        'nbi_total_2018', 'mpio_fronterizo', 'riesgo_victimizacion_2020',
#        'coca19_HA_perc_area', 'produccion_oro_2020_perc',
#        'numero_grupos_armados', 'acto_terrorista_2019_perc',
#        'desaparicion_2019_perc', 'desplazamiento_2019_perc',
#        'tasa_homicidios_2017', 'minas_antipersonales_2020_perc',
#        'tasa_extorsion_2020_perc', 'eova_ilicita_perc_area', 'ipm_2018',
#        'aerodromos_perc', 'mdm_2019', 'va_ppa_2019',
#        'maquinaria_incautada_2020_perc', 'tasa_desempleo_2019',
#        'ingresos_juegos_2019_perc', 'armamento_incautado_2020_perc',
#        'cocaina_incautada_2020_perc', 'marihuana_incautada_2020_perc',
#        'capturados_contrabando_perc', 'cigarrillos_incautados_2017_perc',
#        'capturas_lavado_perc', 'presencia_rios', 'dumm_coca19_HA',
#        'dumm_produccion_oro_2020', 'dumm_acto_terrorista_2019',
#        'dumm_desaparicion_2019', 'dumm_desplazamiento_2019',
#        'dumm_minas_antipersonales_2020', 'dumm_eova_ilicita',
#        'dumm_aerodromos', 'dumm_va_ppa_2019', 'dumm_maquinaria_incautada_2020',
#        'dumm_ingresos_juegos_2019', 'dumm_armamento_incautado_2020',
#        'dumm_cocaina_incautada_2020', 'dumm_marihuana_incautada_2020',
#        'dumm_capturados_contrabando', 'dumm_cigarrillos_incautados_2017',
#        'poblacion_2021', 'maq_ilegalmin_2021', 'vol_oleductos_2021',
#        'vol_torres_2018', 'hurtos_comercio_2021', 'hurtosc_perc_2021',
#        'irac_2018', 'ha_municipal', 'ha_deforestadas_2016', 'deforestacion',
#        'paso_fr', 'puertos', 'suma_zf', 'puerto_libre',
#        'riesgo_electoral_2018', 'hurtos_personas_2021', 'Unnamed: 6',
#        'hurtosp_perc_2021', 'sae_2021', 'solicitudes_tierras_2022', 'gpa_r_x',
#        'gpa_r_y', 'fronterizo_x_va', 'pasofr_x_va', 'puertos_x_va', 'zf_x_va',
#        'rios_x_ha', 'desigualdad'],
#       dtype='object')

# %%
#poner negativas las variables que tienen una relación inversa de riesgo, para que la normalización sea inversa
negativas = ['mdm_2019','va_ppa_2019','gobierno_abierto_2016']

df[negativas] *= -1

# %%
contexto = ['coddane','gobierno_abierto_2016', 'produccion_oro_2020_perc',
            'fronterizo_x_va', 'mdm_2019','ingresos_juegos_2019_perc','tasa_desempleo_2019','desigualdad']

# %%
df1 = df[contexto]

# %%
df1.head()
# Out:
#   coddane  gobierno_abierto_2016  produccion_oro_2020_perc  fronterizo_x_va  \
# 0   05001             -85.594530                       0.0         0.000000
# 1   11001             -85.008696                       0.0         0.000000
# 2   54001             -76.967960                       0.0        12.032173
# 3   08001             -79.552880                       0.0         0.000000
# 4   76001             -74.387320                       0.0         0.000000
#
#     mdm_2019  ingresos_juegos_2019_perc  tasa_desempleo_2019  desigualdad
# 0 -83.595858               0.000000e+00             0.113831   309.105540
# 1 -79.632308               7.221464e+08             0.109023   289.484364
# 2 -67.903241               0.000000e+00             0.141324   309.226857
# 3 -72.386381               1.098686e+07             0.070208   388.748826
# 4 -83.744096               4.439283e+00             0.119149   232.685484

# %%
#normalizar de 0 a 1 con método de mínimos y máximos
scaler = preprocessing.MinMaxScaler()
names = df1.columns
cols = df1.columns.difference(['coddane'])
d = scaler.fit_transform(df1[cols])
sc_df1 = pd.DataFrame(d, columns=cols)
sc_df1.head()
# Out:
#    desigualdad  fronterizo_x_va  gobierno_abierto_2016  \
# 0     0.017711         0.000000               0.058905
# 1     0.016122         0.000000               0.065346
# 2     0.017721         0.115617               0.153752
# 3     0.024160         0.000000               0.125331
# 4     0.011522         0.000000               0.182126
#
#    ingresos_juegos_2019_perc  mdm_2019  produccion_oro_2020_perc  \
# 0               0.000000e+00  0.037102                       0.0
# 1               3.098261e-01  0.082756                       0.0
# 2               0.000000e+00  0.217857                       0.0
# 3               4.713746e-03  0.166218                       0.0
# 4               1.904608e-09  0.035394                       0.0
#
#    tasa_desempleo_2019
# 0             0.737245
# 1             0.706111
# 2             0.915311
# 3             0.454714
# 4             0.771691

# %%
#calcular la media de las filas
sc_df1['score_cs'] = sc_df1.mean(axis=1)

# %%
#unir municipios con sus valores
sc_df1 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc_df1], axis = 1)
sc_df1['score_cs']=sc_df1['score_cs'].round(decimals = 3)
sc_df1.head()
# Out:
#   coddane              MPIO_y             DPNOM_x  desigualdad  \
# 0   05001            Medellín           Antioquia     0.017711
# 1   11001        Bogotá, D.C.        Bogotá, D.C.     0.016122
# 2   54001  San José de Cúcuta  Norte de Santander     0.017721
# 3   08001        Barranquilla           Atlántico     0.024160
# 4   76001                Cali     Valle del Cauca     0.011522
#
#    fronterizo_x_va  gobierno_abierto_2016  ingresos_juegos_2019_perc  \
# 0         0.000000               0.058905               0.000000e+00
# 1         0.000000               0.065346               3.098261e-01
# 2         0.115617               0.153752               0.000000e+00
# 3         0.000000               0.125331               4.713746e-03
# 4         0.000000               0.182126               1.904608e-09
#
#    mdm_2019  produccion_oro_2020_perc  tasa_desempleo_2019  score_cs
# 0  0.037102                       0.0             0.737245     0.122
# 1  0.082756                       0.0             0.706111     0.169
# 2  0.217857                       0.0             0.915311     0.203
# 3  0.166218                       0.0             0.454714     0.111
# 4  0.035394                       0.0             0.771691     0.143

# %%
#dataframe con el score
cs = sc_df1[['coddane','score_cs']]

#volver a normalizar
scaler = preprocessing.MinMaxScaler()
names = cs.columns
cols = cs.columns.difference(['coddane'])
d = scaler.fit_transform(cs[cols])
sc2_df1 = pd.DataFrame(d, columns=cols)
sc2_df1.head()
# Out:
#    score_cs
# 0  0.191950
# 1  0.337461
# 2  0.442724
# 3  0.157895
# 4  0.256966

# %% [markdown]
# ## Unir variables

# %%
#unir nuevamente para construir el df
sc2_df1 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc2_df1], axis = 1)
cs = sc2_df1[['coddane', 'MPIO_y','DPNOM_x','score_cs']]

# %%
#ranking componente de contexto socioeconómico
cs.sort_values(by = 'score_cs', ascending=False)
# Out:
#     coddane                 MPIO_y     DPNOM_x  score_cs
# 312   20045               Becerril       Cesar  1.000000
# 527   05113               Buriticá   Antioquia  0.978328
# 995   27810     Unión Panamericana       Chocó  0.869969
# 166   44078              Barrancas  La Guajira  0.863777
# 238   05604               Remedios   Antioquia  0.860681
# ..      ...                    ...         ...       ...
# 99    95001  San José del Guaviare    Guaviare  0.049536
# 161   85139                   Maní    Casanare  0.027864
# 20    85001                  Yopal    Casanare  0.009288
# 229   85162              Monterrey    Casanare  0.006192
# 719   85300            Sabanalarga    Casanare  0.000000
#
# [1122 rows x 4 columns]

# %% [markdown]
# Infraestructura

# %%
infraestructura =['coddane', 'rios_x_ha', 'maq_ilegalmin_2021','aerodromos_perc','vol_oleductos_2021','vol_torres_2018','zf_x_va','puertos_x_va','pasofr_x_va']

# %%
df2 = df[infraestructura]

# %%
scaler = preprocessing.MinMaxScaler()
names = df2.columns
cols = df2.columns.difference(['coddane'])
d = scaler.fit_transform(df2[cols])
sc_df2 = pd.DataFrame(d, columns=cols)
sc_df2.head()
# Out:
#    aerodromos_perc  maq_ilegalmin_2021  pasofr_x_va  puertos_x_va  rios_x_ha  \
# 0         0.000000            0.000000          0.0           0.0   0.000000
# 1         0.001605            0.108844          0.0           0.0   0.000000
# 2         0.010663            0.000000          1.0           0.0   0.000000
# 3         0.000000            0.006803          0.0           0.0   0.272686
# 4         0.000000            0.000000          0.0           0.0   0.000000
#
#    vol_oleductos_2021  vol_torres_2018   zf_x_va
# 0                 0.0              0.0  0.116861
# 1                 0.0              0.0  0.311303
# 2                 0.0              0.0  0.116452
# 3                 0.0              0.0  0.324349
# 4                 0.0              0.0  0.094622

# %%
#calcular la media de las filas
sc_df2['score_inf'] = sc_df2.mean(axis=1)

# %%
#unir municipios con sus valores
sc_df2 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc_df2], axis = 1)
sc_df2['score_inf']=sc_df2['score_inf'].round(decimals = 3)
sc_df2.head()
# Out:
#   coddane              MPIO_y             DPNOM_x  aerodromos_perc  \
# 0   05001            Medellín           Antioquia         0.000000
# 1   11001        Bogotá, D.C.        Bogotá, D.C.         0.001605
# 2   54001  San José de Cúcuta  Norte de Santander         0.010663
# 3   08001        Barranquilla           Atlántico         0.000000
# 4   76001                Cali     Valle del Cauca         0.000000
#
#    maq_ilegalmin_2021  pasofr_x_va  puertos_x_va  rios_x_ha  \
# 0            0.000000          0.0           0.0   0.000000
# 1            0.108844          0.0           0.0   0.000000
# 2            0.000000          1.0           0.0   0.000000
# 3            0.006803          0.0           0.0   0.272686
# 4            0.000000          0.0           0.0   0.000000
#
#    vol_oleductos_2021  vol_torres_2018   zf_x_va  score_inf
# 0                 0.0              0.0  0.116861      0.015
# 1                 0.0              0.0  0.311303      0.053
# 2                 0.0              0.0  0.116452      0.141
# 3                 0.0              0.0  0.324349      0.075
# 4                 0.0              0.0  0.094622      0.012

# %%
#dataframe con el score
inf = sc_df2[['coddane','score_inf']]

#volver a normalizar
scaler = preprocessing.MinMaxScaler()
names = inf.columns
cols = inf.columns.difference(['coddane'])
d = scaler.fit_transform(inf[cols])
sc2_df2 = pd.DataFrame(d, columns=cols)
sc2_df2.head()
# Out:
#    score_inf
# 0   0.072115
# 1   0.254808
# 2   0.677885
# 3   0.360577
# 4   0.057692

# %%
#unir nuevamente para construir el df
sc2_df2 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc2_df2], axis = 1)
inf = sc2_df2[['coddane', 'MPIO_y','DPNOM_x','score_inf']]

# %%
#ranking componente de infraestructura
inf.sort_values(by = 'score_inf', ascending=False)
# Out:
#     coddane                MPIO_y                     DPNOM_x  score_inf
# 973   88564           Providencia  Archipiélago de San Andrés   1.000000
# 2     54001    San José de Cúcuta          Norte de Santander   0.677885
# 363   81736              Saravena                      Arauca   0.668269
# 47    52835  San Andrés de Tumaco                      Nariño   0.634615
# 311   05495                 Nechí                   Antioquia   0.629808
# ..      ...                   ...                         ...        ...
# 602   15542                 Pesca                      Boyacá   0.000000
# 603   47545     Pijiño del Carmen                   Magdalena   0.000000
# 604   81300                Fortul                      Arauca   0.000000
# 220   17873            Villamaría                      Caldas   0.000000
# 561   13810              Tiquisio                     Bolívar   0.000000
#
# [1122 rows x 4 columns]

# %% [markdown]
# Criminalidad

# %%
criminalidad = ['coddane','coca19_HA_perc_area','eova_ilicita_perc_area','cigarrillos_incautados_2017_perc',
               'capturados_contrabando_perc','capturas_lavado_perc','tasa_homicidios_2017',
                'marihuana_incautada_2020_perc','cocaina_incautada_2020_perc','hurtosc_perc_2021',
                'hurtosp_perc_2021','sae_2021','riesgo_electoral_2018']

df3 = df[criminalidad]

# %%
scaler = preprocessing.MinMaxScaler()
names = df3.columns
cols = df3.columns.difference(['coddane'])
d = scaler.fit_transform(df3[cols])
sc_df3 = pd.DataFrame(d, columns=cols)
sc_df3.head()
# Out:
#    capturados_contrabando_perc  capturas_lavado_perc  \
# 0                     0.000000                   0.0
# 1                     0.026177                   0.0
# 2                     0.298121                   0.0
# 3                     0.056816                   0.0
# 4                     0.025711                   0.0
#
#    cigarrillos_incautados_2017_perc  coca19_HA_perc_area  \
# 0                          0.000445             0.000000
# 1                          0.000053             0.000000
# 2                          0.001705             0.028628
# 3                          0.001679             0.000000
# 4                          0.000432             0.000000
#
#    cocaina_incautada_2020_perc  eova_ilicita_perc_area  hurtosc_perc_2021  \
# 0                     0.000295                     0.0           0.387831
# 1                     0.000332                     0.0           0.413356
# 2                     0.000088                     0.0           0.198538
# 3                     0.004783                     0.0           0.320130
# 4                     0.000434                     0.0           0.493570
#
#    hurtosp_perc_2021  marihuana_incautada_2020_perc  riesgo_electoral_2018  \
# 0           0.654431                       0.000972                    0.0
# 1           1.000000                       0.002451                    1.0
# 2           0.269389                       0.000962                    1.0
# 3           0.585157                       0.000515                    0.0
# 4           0.596615                       0.020747                    1.0
#
#    sae_2021  tasa_homicidios_2017
# 0  0.033333              0.084944
# 1  0.000000              0.052338
# 2  0.000000              0.140583
# 3  0.000000              0.107207
# 4  0.096296              0.188080

# %%
#calcular la media de las filas
sc_df3['score_cri'] = sc_df3.mean(axis=1)

# %%
#unir municipios con sus valores
sc_df3 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc_df3], axis = 1)
sc_df3['score_cri']=sc_df3['score_cri'].round(decimals = 3)
sc_df3.head()
# Out:
#   coddane              MPIO_y             DPNOM_x  \
# 0   05001            Medellín           Antioquia
# 1   11001        Bogotá, D.C.        Bogotá, D.C.
# 2   54001  San José de Cúcuta  Norte de Santander
# 3   08001        Barranquilla           Atlántico
# 4   76001                Cali     Valle del Cauca
#
#    capturados_contrabando_perc  capturas_lavado_perc  \
# 0                     0.000000                   0.0
# 1                     0.026177                   0.0
# 2                     0.298121                   0.0
# 3                     0.056816                   0.0
# 4                     0.025711                   0.0
#
#    cigarrillos_incautados_2017_perc  coca19_HA_perc_area  \
# 0                          0.000445             0.000000
# 1                          0.000053             0.000000
# 2                          0.001705             0.028628
# 3                          0.001679             0.000000
# 4                          0.000432             0.000000
#
#    cocaina_incautada_2020_perc  eova_ilicita_perc_area  hurtosc_perc_2021  \
# 0                     0.000295                     0.0           0.387831
# 1                     0.000332                     0.0           0.413356
# 2                     0.000088                     0.0           0.198538
# 3                     0.004783                     0.0           0.320130
# 4                     0.000434                     0.0           0.493570
#
#    hurtosp_perc_2021  marihuana_incautada_2020_perc  riesgo_electoral_2018  \
# 0           0.654431                       0.000972                    0.0
# 1           1.000000                       0.002451                    1.0
# 2           0.269389                       0.000962                    1.0
# 3           0.585157                       0.000515                    0.0
# 4           0.596615                       0.020747                    1.0
#
#    sae_2021  tasa_homicidios_2017  score_cri
# 0  0.033333              0.084944      0.097
# 1  0.000000              0.052338      0.208
# 2  0.000000              0.140583      0.162
# 3  0.000000              0.107207      0.090
# 4  0.096296              0.188080      0.202

# %%
#dataframe con el score
cri = sc_df3[['coddane','score_cri']]

#volver a normalizar
scaler = preprocessing.MinMaxScaler()
names = cri.columns
cols = cri.columns.difference(['coddane'])
d = scaler.fit_transform(cri[cols])
sc2_df3 = pd.DataFrame(d, columns=cols)
sc2_df3.head()
# Out:
#    score_cri
# 0   0.411017
# 1   0.881356
# 2   0.686441
# 3   0.381356
# 4   0.855932

# %%
#unir nuevamente para construir el df
sc2_df3 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc2_df3], axis = 1)
cri = sc2_df3[['coddane', 'MPIO_y','DPNOM_x','score_cri']]

# %%
#ranking componente de criminalidad
cri.sort_values(by = 'score_cri', ascending=False)
# Out:
#      coddane         MPIO_y             DPNOM_x  score_cri
# 210    54810           Tibú  Norte de Santander   1.000000
# 1      11001   Bogotá, D.C.        Bogotá, D.C.   0.881356
# 769    54250       El Tarra  Norte de Santander   0.881356
# 4      76001           Cali     Valle del Cauca   0.855932
# 26     19001        Popayán               Cauca   0.851695
# ...      ...            ...                 ...        ...
# 830    15114       Busbanzá              Boyacá   0.000000
# 820    15832       Tununguá              Boyacá   0.000000
# 1034   15276       Floresta              Boyacá   0.000000
# 786    68673     San Benito           Santander   0.000000
# 1121   97889  Yavaraté (CD)              Vaupés   0.000000
#
# [1122 rows x 4 columns]

# %% [markdown]
# Conflicto armado

# %%
df.columns
# Out:
# Index(['coddane', 'MPIO_y', 'DPNOM_x', 'gobierno_abierto_2016',
#        'nbi_total_2018', 'mpio_fronterizo', 'riesgo_victimizacion_2020',
#        'coca19_HA_perc_area', 'produccion_oro_2020_perc',
#        'numero_grupos_armados', 'acto_terrorista_2019_perc',
#        'desaparicion_2019_perc', 'desplazamiento_2019_perc',
#        'tasa_homicidios_2017', 'minas_antipersonales_2020_perc',
#        'tasa_extorsion_2020_perc', 'eova_ilicita_perc_area', 'ipm_2018',
#        'aerodromos_perc', 'mdm_2019', 'va_ppa_2019',
#        'maquinaria_incautada_2020_perc', 'tasa_desempleo_2019',
#        'ingresos_juegos_2019_perc', 'armamento_incautado_2020_perc',
#        'cocaina_incautada_2020_perc', 'marihuana_incautada_2020_perc',
#        'capturados_contrabando_perc', 'cigarrillos_incautados_2017_perc',
#        'capturas_lavado_perc', 'presencia_rios', 'dumm_coca19_HA',
#        'dumm_produccion_oro_2020', 'dumm_acto_terrorista_2019',
#        'dumm_desaparicion_2019', 'dumm_desplazamiento_2019',
#        'dumm_minas_antipersonales_2020', 'dumm_eova_ilicita',
#        'dumm_aerodromos', 'dumm_va_ppa_2019', 'dumm_maquinaria_incautada_2020',
#        'dumm_ingresos_juegos_2019', 'dumm_armamento_incautado_2020',
#        'dumm_cocaina_incautada_2020', 'dumm_marihuana_incautada_2020',
#        'dumm_capturados_contrabando', 'dumm_cigarrillos_incautados_2017',
#        'poblacion_2021', 'maq_ilegalmin_2021', 'vol_oleductos_2021',
#        'vol_torres_2018', 'hurtos_comercio_2021', 'hurtosc_perc_2021',
#        'irac_2018', 'ha_municipal', 'ha_deforestadas_2016', 'deforestacion',
#        'paso_fr', 'puertos', 'suma_zf', 'puerto_libre',
#        'riesgo_electoral_2018', 'hurtos_personas_2021', 'Unnamed: 6',
#        'hurtosp_perc_2021', 'sae_2021', 'solicitudes_tierras_2022', 'gpa_r_x',
#        'gpa_r_y', 'fronterizo_x_va', 'pasofr_x_va', 'puertos_x_va', 'zf_x_va',
#        'rios_x_ha', 'desigualdad'],
#       dtype='object')

# %%
conflicto = ['coddane', 'numero_grupos_armados','acto_terrorista_2019_perc','tasa_extorsion_2020_perc',
            'riesgo_victimizacion_2020','desaparicion_2019_perc','desplazamiento_2019_perc',
             'minas_antipersonales_2020_perc','armamento_incautado_2020_perc','solicitudes_tierras_2022','gpa_r_y']

df4 = df[conflicto]

# %%
scaler = preprocessing.MinMaxScaler()
names = df4.columns
cols = df4.columns.difference(['coddane'])
d = scaler.fit_transform(df4[cols])
sc_df4 = pd.DataFrame(d, columns=cols)
sc_df4.head()
# Out:
#    acto_terrorista_2019_perc  armamento_incautado_2020_perc  \
# 0                   0.000000                       0.002521
# 1                   0.001578                       0.000433
# 2                   0.000000                       0.005548
# 3                   0.000000                       0.000000
# 4                   0.000000                       0.001205
#
#    desaparicion_2019_perc  desplazamiento_2019_perc  gpa_r_y  \
# 0                0.000000                  0.002192      0.0
# 1                0.000000                  0.000084      0.0
# 2                0.007501                  0.002793      0.0
# 3                0.000000                  0.000270      0.0
# 4                0.000000                  0.000762      0.0
#
#    minas_antipersonales_2020_perc  numero_grupos_armados  \
# 0                        0.000000               0.444444
# 1                        0.000000               0.000000
# 2                        0.003368               0.111111
# 3                        0.000000               0.000000
# 4                        0.000000               0.055556
#
#    riesgo_victimizacion_2020  solicitudes_tierras_2022  \
# 0                   0.191146                  0.000000
# 1                   0.131234                  0.147929
# 2                   0.193334                  0.274951
# 3                   0.110527                  0.000000
# 4                   0.188152                  0.121893
#
#    tasa_extorsion_2020_perc
# 0                  0.000096
# 1                  0.000021
# 2                  0.000269
# 3                  0.000091
# 4                  0.000128

# %%
#calcular la media de las filas
sc_df4['score_con'] = sc_df4.mean(axis=1)

# %%
#unir municipios con sus valores
sc_df4 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc_df4], axis = 1)
sc_df4['score_con']=sc_df4['score_con'].round(decimals = 3)
sc_df4.head()
# Out:
#   coddane              MPIO_y             DPNOM_x  acto_terrorista_2019_perc  \
# 0   05001            Medellín           Antioquia                   0.000000
# 1   11001        Bogotá, D.C.        Bogotá, D.C.                   0.001578
# 2   54001  San José de Cúcuta  Norte de Santander                   0.000000
# 3   08001        Barranquilla           Atlántico                   0.000000
# 4   76001                Cali     Valle del Cauca                   0.000000
#
#    armamento_incautado_2020_perc  desaparicion_2019_perc  \
# 0                       0.002521                0.000000
# 1                       0.000433                0.000000
# 2                       0.005548                0.007501
# 3                       0.000000                0.000000
# 4                       0.001205                0.000000
#
#    desplazamiento_2019_perc  gpa_r_y  minas_antipersonales_2020_perc  \
# 0                  0.002192      0.0                        0.000000
# 1                  0.000084      0.0                        0.000000
# 2                  0.002793      0.0                        0.003368
# 3                  0.000270      0.0                        0.000000
# 4                  0.000762      0.0                        0.000000
#
#    numero_grupos_armados  riesgo_victimizacion_2020  solicitudes_tierras_2022  \
# 0               0.444444                   0.191146                  0.000000
# 1               0.000000                   0.131234                  0.147929
# 2               0.111111                   0.193334                  0.274951
# 3               0.000000                   0.110527                  0.000000
# 4               0.055556                   0.188152                  0.121893
#
#    tasa_extorsion_2020_perc  score_con
# 0                  0.000096      0.064
# 1                  0.000021      0.028
# 2                  0.000269      0.060
# 3                  0.000091      0.011
# 4                  0.000128      0.037

# %%
sc_df4.shape
# Out:
# (1122, 14)

# %%
sc_df4['coddane'].nunique()
# Out:
# 1121

# %%
sc_df4[sc_df4['coddane']=='05266'].transpose()
# Out:
#                                        34
# coddane                             05266
# MPIO_y                           Envigado
# DPNOM_x                         Antioquia
# acto_terrorista_2019_perc             0.0
# armamento_incautado_2020_perc         0.0
# desaparicion_2019_perc                0.0
# desplazamiento_2019_perc              0.0
# gpa_r_y                               0.0
# minas_antipersonales_2020_perc        0.0
# numero_grupos_armados            0.055556
# riesgo_victimizacion_2020        0.061755
# solicitudes_tierras_2022              0.0
# tasa_extorsion_2020_perc         0.000708
# score_con                           0.012

# %%
#dataframe con el score
con = sc_df4[['coddane','score_con']]

#volver a normalizar
scaler = preprocessing.MinMaxScaler()
names = con.columns
cols = con.columns.difference(['coddane'])
d = scaler.fit_transform(con[cols])
sc2_df4 = pd.DataFrame(d, columns=cols)
sc2_df4.head()
# Out:
#    score_con
# 0   0.166234
# 1   0.072727
# 2   0.155844
# 3   0.028571
# 4   0.096104

# %%
#unir nuevamente para construir el df
sc2_df4 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc2_df4], axis = 1)
con = sc2_df4[['coddane', 'MPIO_y','DPNOM_x','score_con']]

# %%
#ranking componente de conflicto armado
con.sort_values(by = 'score_con', ascending=False)
# Out:
#      coddane                MPIO_y             DPNOM_x  score_con
# 278    05790                Tarazá           Antioquia   1.000000
# 965    54344                Hacarí  Norte de Santander   0.880519
# 1004   54800               Teorama  Norte de Santander   0.859740
# 47     52835  San Andrés de Tumaco              Nariño   0.818182
# 210    54810                  Tibú  Norte de Santander   0.800000
# ...      ...                   ...                 ...        ...
# 983    15522              Panqueba              Boyacá   0.002597
# 935    25299                  Gama        Cundinamarca   0.002597
# 905    25372                 Junín        Cundinamarca   0.002597
# 1059   15317            Guacamayas              Boyacá   0.000000
# 900    15810             Tipacoque              Boyacá   0.000000
#
# [1122 rows x 4 columns]

# %% [markdown]
# Ambiental

# %%
ambiental = ['irac_2018','ha_deforestadas_2016'] 
df5 = df[ambiental]

# %%
#scaler = preprocessing.MinMaxScaler()
names = df5.columns
cols = df5.columns.difference(['coddane'])
d = scaler.fit_transform(df5[cols])
sc_df5 = pd.DataFrame(d, columns=cols)
sc_df5.head()
# Out:
#    ha_deforestadas_2016  irac_2018
# 0              0.002924   0.187741
# 1              0.000092   0.102808
# 2              0.017244   0.378487
# 3              0.000202   0.181618
# 4              0.000215   0.295097

# %%
#calcular la media de las filas
sc_df5['score_amb'] = sc_df5.mean(axis=1)

# %%
#unir municipios con sus valores
sc_df5 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc_df5], axis = 1)
sc_df5['score_amb']=sc_df5['score_amb'].round(decimals = 3)
sc_df5.head()
# Out:
#   coddane              MPIO_y             DPNOM_x  ha_deforestadas_2016  \
# 0   05001            Medellín           Antioquia              0.002924
# 1   11001        Bogotá, D.C.        Bogotá, D.C.              0.000092
# 2   54001  San José de Cúcuta  Norte de Santander              0.017244
# 3   08001        Barranquilla           Atlántico              0.000202
# 4   76001                Cali     Valle del Cauca              0.000215
#
#    irac_2018  score_amb
# 0   0.187741      0.095
# 1   0.102808      0.051
# 2   0.378487      0.198
# 3   0.181618      0.091
# 4   0.295097      0.148

# %%
#dataframe con el score
amb = sc_df5[['coddane','score_amb']]

#volver a normalizar
scaler = preprocessing.MinMaxScaler()
names = amb.columns
cols = amb.columns.difference(['coddane'])
d = scaler.fit_transform(amb[cols])
sc2_df5 = pd.DataFrame(d, columns=cols)
sc2_df5.head()
# Out:
#    score_amb
# 0   0.110981
# 1   0.059579
# 2   0.231308
# 3   0.106308
# 4   0.172897

# %%
#unir nuevamente para construir el df
sc2_df5 = pd.concat([df[['coddane', 'MPIO_y', 'DPNOM_x']],sc2_df5], axis = 1)
amb = sc2_df5[['coddane', 'MPIO_y','DPNOM_x','score_amb']]

# %%
#ranking componente de ambiental
amb.sort_values(by = 'score_amb', ascending=False)
# Out:
#     coddane                  MPIO_y       DPNOM_x  score_amb
# 375   27615                Riosucio         Chocó   1.000000
# 737   27800                  Unguía         Chocó   0.853972
# 41    18753  San Vicente del Caguán       Caquetá   0.831776
# 685   50370                   Uribe          Meta   0.761682
# 319   18150    Cartagena del Chairá       Caquetá   0.733645
# ..      ...                     ...           ...        ...
# 1     11001            Bogotá, D.C.  Bogotá, D.C.   0.059579
# 157   08573         Puerto Colombia     Atlántico   0.058411
# 229   85162               Monterrey      Casanare   0.054907
# 228   50150       Castilla la Nueva          Meta   0.031542
# 34    05266                Envigado     Antioquia   0.000000
#
# [1122 rows x 4 columns]

# %% [markdown]
# Score global VereData

# %%
#se unen los componentes
score_global = cs.merge(inf, on=['coddane','MPIO_y','DPNOM_x'], how='left')
score_global = score_global.merge(cri, on=['coddane','MPIO_y','DPNOM_x'], how='left')
score_global = score_global.merge(con, on=['coddane','MPIO_y','DPNOM_x'], how='left')
score_global = score_global.merge(amb, on=['coddane','MPIO_y','DPNOM_x'], how='left')

# %%
score_global['score_global']=score_global[['score_cs','score_inf','score_cri','score_con','score_amb']].mean(axis=1)

# %%
sg_ranking = score_global.sort_values(by='score_global', ascending =False)
sg_ranking.head(20)
# Out:
#      coddane                  MPIO_y             DPNOM_x  score_cs  score_inf  \
# 210    54810                    Tibú  Norte de Santander  0.625387   0.245192
# 47     52835    San Andrés de Tumaco              Nariño  0.433437   0.634615
# 769    54250                El Tarra  Norte de Santander  0.557276   0.000000
# 278    05790                  Tarazá           Antioquia  0.619195   0.413462
# 1034   54800                 Teorama  Norte de Santander  0.541796   0.000000
# 249    05854                Valdivia           Antioquia  0.464396   0.447115
# 995    54344                  Hacarí  Norte de Santander  0.501548   0.000000
# 851    54670             San Calixto  Norte de Santander  0.541796   0.000000
# 2      54001      San José de Cúcuta  Norte de Santander  0.442724   0.677885
# 1112   27660     San José del Palmar               Chocó  0.455108   0.000000
# 738    54206              Convención  Norte de Santander  0.606811   0.052885
# 201    19212                 Corinto               Cauca  0.408669   0.000000
# 375    27615                Riosucio               Chocó  0.538700   0.004808
# 685    50370                   Uribe                Meta  0.482972   0.004808
# 476    54245               El Carmen  Norte de Santander  0.557276   0.000000
# 1106   27372                  Juradó               Chocó  0.501548   0.000000
# 544    54720               Sardinata  Norte de Santander  0.600619   0.000000
# 41     18753  San Vicente del Caguán             Caquetá  0.349845   0.048077
# 560    05361                 Ituango           Antioquia  0.616099   0.201923
# 238    05604                Remedios           Antioquia  0.860681   0.302885
#
#       score_cri  score_con  score_amb  score_global
# 210    1.000000   0.800000   0.556075      0.645331
# 47     0.686441   0.818182   0.337617      0.582058
# 769    0.881356   0.657143   0.664720      0.552099
# 278    0.237288   1.000000   0.375000      0.528989
# 1034   0.648305   0.859740   0.417056      0.493379
# 249    0.466102   0.566234   0.431075      0.474984
# 995    0.504237   0.880519   0.413551      0.459971
# 851    0.402542   0.766234   0.511682      0.444451
# 2      0.686441   0.155844   0.231308      0.438840
# 1112   0.716102   0.464935   0.542056      0.435640
# 738    0.652542   0.581818   0.281542      0.435120
# 201    0.720339   0.750649   0.292056      0.434343
# 375    0.084746   0.514286   1.000000      0.428508
# 685    0.529661   0.324675   0.761682      0.420760
# 476    0.576271   0.415584   0.544393      0.418705
# 1106   0.436441   0.703896   0.432243      0.414826
# 544    0.330508   0.680519   0.461449      0.414619
# 41     0.334746   0.488312   0.831776      0.410551
# 560    0.173729   0.672727   0.363318      0.405559
# 238    0.152542   0.345455   0.338785      0.400070

# %%
sg_ranking.tail(20)
# Out:
#      coddane       MPIO_y    DPNOM_x  score_cs  score_inf  score_cri  \
# 283    15491        Nobsa     Boyacá  0.340557   0.000000   0.097458
# 366    85263         Pore   Casanare  0.086687   0.000000   0.148305
# 116    85410    Tauramena   Casanare  0.102167   0.009615   0.135593
# 629    13222    Clemencia    Bolívar  0.275542   0.000000   0.050847
# 114    85440   Villanueva   Casanare  0.102167   0.028846   0.148305
# 1044   97161       Carurú     Vaupés  0.126935   0.004808   0.016949
# 726    52210    Contadero     Nariño  0.213622   0.000000   0.021186
# 495    15367     Jenesano     Boyacá  0.229102   0.000000   0.021186
# 938    68121      Cabrera  Santander  0.284830   0.000000   0.000000
# 1085   15187      Chivatá     Boyacá  0.244582   0.000000   0.042373
# 556    15806     Tibasosa     Boyacá  0.238390   0.000000   0.050847
# 656    15104       Boyacá     Boyacá  0.297214   0.000000   0.000000
# 885    15696  Santa Sofía     Boyacá  0.256966   0.000000   0.000000
# 1011   15500       Oicatá     Boyacá  0.272446   0.000000   0.016949
# 1149   97666      Taraira     Vaupés  0.232198   0.000000   0.008475
# 161    85139         Maní   Casanare  0.027864   0.004808   0.177966
# 376    86749     Sibundoy   Putumayo  0.071207   0.000000   0.050847
# 590    86219        Colón   Putumayo  0.055728   0.000000   0.021186
# 719    85300  Sabanalarga   Casanare  0.000000   0.000000   0.118644
# 229    85162    Monterrey   Casanare  0.006192   0.000000   0.144068
#
#       score_con  score_amb  score_global
# 283    0.023377   0.084112      0.109101
# 366    0.075325   0.227804      0.107624
# 116    0.090909   0.195093      0.106676
# 629    0.033766   0.172897      0.106611
# 114    0.049351   0.195093      0.104753
# 1044   0.174026   0.197430      0.104030
# 726    0.015584   0.267523      0.103583
# 495    0.012987   0.242991      0.101253
# 938    0.010390   0.207944      0.100633
# 1085   0.018182   0.197430      0.100513
# 556    0.020779   0.184579      0.098919
# 656    0.015584   0.169393      0.096438
# 885    0.010390   0.213785      0.096228
# 1011   0.018182   0.162383      0.093992
# 1149   0.025974   0.141355      0.081600
# 161    0.059740   0.133178      0.080711
# 376    0.031169   0.196262      0.069897
# 590    0.051948   0.188084      0.063389
# 719    0.028571   0.169393      0.063322
# 229    0.054545   0.054907      0.051942

# %% [markdown]
# # Reportes

# %%
def reporte_componente (coddane, sc_dfx):
    """Retorna reporte por componente del municipio
        Parámetros: 
            coddane (str): Código Dane del municipio de 5 dígitos
            sc_dfx : dataframes por componentes, donde 1 es contexto, 2 es infraestructura, 3 criminalidad, 4 conflicto y 5 ambiental
            
            """
    #sg_base=sg_base[componente]
    
    reporte_componente = pd.concat([sc_dfx[sc_dfx['coddane']==coddane].transpose(), sc_dfx.mean()], axis=1)
        
    reporte_componente.columns = ['municipio', 'media_nacional']
    
    reporte_componente.drop(['coddane'], inplace=True)

    reporte_componente.reset_index(inplace=True)
    
    return reporte_componente

# %%
reporte_componente('05266',sc_df3)
# Out:
#                                index  municipio  media_nacional
# 0                             MPIO_y   Envigado             NaN
# 1                            DPNOM_x  Antioquia             NaN
# 2        capturados_contrabando_perc        0.0        0.002823
# 3               capturas_lavado_perc        0.0        0.001394
# 4   cigarrillos_incautados_2017_perc   0.012394        0.004197
# 5                coca19_HA_perc_area        0.0        0.011152
# 6        cocaina_incautada_2020_perc   0.000004        0.009003
# 7             eova_ilicita_perc_area        0.0        0.005225
# 8                  hurtosc_perc_2021   0.423005        0.109558
# 9                  hurtosp_perc_2021   0.451059        0.081779
# 10     marihuana_incautada_2020_perc   0.016167        0.019010
# 11             riesgo_electoral_2018        0.0        0.092989
# 12                          sae_2021   0.011111        0.003605
# 13              tasa_homicidios_2017   0.017312        0.086518
# 14                         score_cri      0.078        0.035619

# %%
reporte_componente('50150',sc_df2)
# Out:
#                  index          municipio  media_nacional
# 0               MPIO_y  Castilla la Nueva             NaN
# 1              DPNOM_x               Meta             NaN
# 2      aerodromos_perc                0.0        0.009641
# 3   maq_ilegalmin_2021                0.0        0.006299
# 4          pasofr_x_va                0.0        0.003062
# 5         puertos_x_va                0.0        0.002038
# 6            rios_x_ha                0.0        0.017228
# 7   vol_oleductos_2021                0.0        0.002350
# 8      vol_torres_2018                0.0        0.003565
# 9              zf_x_va                0.0        0.008578
# 10           score_inf                0.0        0.006601

# %%
ranking_crim = sc_df3.sort_values(by='score_cri',ascending=False)
ranking_crim.head(20)

# %%
ranking_crim.tail(20)
